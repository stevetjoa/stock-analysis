# %% [markdown]
# # Stock Analysis

# %% [markdown]
# This notebook analyzes some securities -- stocks, bonds, commodities -- computes their correlations, and optimizes risk vs. reward for a set of portfolio scenarios.

# %% [markdown]
# Select "Run All" to update this notebook with the latest stock quotes.

# %% [markdown]
# Caveat: This analysis covers a date range starting around 2007 (if run without modification). Obviously, the analysis can vary dramatically if you choose another date range.

# %% [markdown]
# ### Initialization

# %%
from sklearn import cluster  # machine learning
import pandas             # data manipulation and computation
import ystockquote as ys  # stock prices

# %%
rcParams['figure.figsize'] = (13, 6)  # default figure size

# %% [markdown]
# ## 1. Data Collection

# %% [markdown]
# ### Choose a few securities.

# %%
symbols = array([
           'blv',  # bond: long-term bond
           'bnd',  # bond: total bond market
           'bsv',  # bond: short-term bond
           'gld',  # commodity: gold (SPDR)
           'iau',  # commodity: gold (iShares)
           'slv',  # commodity: silver
           'vti',  # stock: US total stock market
           'vbk',  # stock: US small-cap stock
           'aapl', # stock: Apple
           'ua',   # stock: Under Armour
           'cmg',  # stock: Chipotle
          ])

# %% [markdown]
# ### Get daily close prices.

# %%
prices = pandas.DataFrame({
             symbol: {
                 date: quote['Adj Close'] 
                 for date, quote in ys.get_historical_prices(symbol, '2000-01-01', '2015-01-01').iteritems()
             }
             for symbol in symbols
         }, columns=symbols, dtype=float)
prices
# Out:
#               blv    bnd    bsv     gld    iau    slv     vti     vbk    aapl  \
# 2000-01-03    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.80
# 2000-01-04    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.48
# 2000-01-05    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.53
# 2000-01-06    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.23
# 2000-01-07    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.38
# 2000-01-10    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.32
# 2000-01-11    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.15
# 2000-01-12    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    2.96
# 2000-01-13    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.29
# 2000-01-14    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.41
# 2000-01-18    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.53
# 2000-01-19    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.62
# 2000-01-20    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.86
# 2000-01-21    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.78
# 2000-01-24    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.61
# 2000-01-25    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.81
# 2000-01-26    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.74
# 2000-01-27    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.74
# 2000-01-28    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.45
# 2000-01-31    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.52
# 2000-02-01    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.41
# 2000-02-02    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.36
# 2000-02-03    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.51
# 2000-02-04    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.67
# 2000-02-07    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.87
# 2000-02-08    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.90
# 2000-02-09    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.83
# 2000-02-10    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.86
# 2000-02-11    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.69
# 2000-02-14    NaN    NaN    NaN     NaN    NaN    NaN     NaN     NaN    3.93
# ...           ...    ...    ...     ...    ...    ...     ...     ...     ...
# 2014-07-21  90.23  81.94  80.08  126.34  12.72  20.10  101.90  122.91   93.48
# 2014-07-22  90.40  82.05  80.13  125.74  12.66  20.10  102.42  123.91   94.25
# 2014-07-23  90.42  82.01  80.12  125.62  12.64  20.08  102.66  124.34   96.71
# 2014-07-24  89.88  81.85  80.08  124.35  12.53  19.58  102.68  124.52   96.55
# 2014-07-25  90.49  82.00  80.09  125.79  12.67  19.87  102.14  123.46   97.19
# 2014-07-28  90.46  81.98  80.06  125.58  12.65  19.81  102.11  123.02   98.53
# 2014-07-29  90.66  82.05  80.07  125.20  12.60  19.78  101.74  123.26   97.89
# 2014-07-30  89.64  81.74  80.00  124.83  12.57  19.78  101.81  123.59   97.66
# 2014-07-31  89.27  81.65  79.99  123.39  12.42  19.58   99.74  120.72   95.13
# 2014-08-27  92.15  82.47  80.22  123.32  12.41  18.66  103.68  126.09  102.13
# 2014-08-28  92.63  82.58  80.22  124.00  12.49  18.74  103.57  125.60  102.25
# 2014-08-29  92.82  82.58  80.27  123.86  12.46  18.71  103.88  126.43  102.50
#
#                ua     cmg
# 2007-04-10  13.26   64.67
# 2007-04-11  13.17   63.78
# 2007-04-12  13.16   64.16
# 2007-04-13  12.97   64.07
# 2007-04-16  13.13   65.20
# 2007-04-17  12.99   66.54
# 2007-04-18  12.68   66.25
# 2007-04-19  12.76   65.37
# 2007-04-20  12.87   65.59
# 2007-04-23  12.70   65.51
# 2007-04-24  12.52   65.00
# 2007-04-25  12.75   65.68
# 2007-04-26  12.40   66.94
# 2007-04-27  12.33   66.02
# 2007-04-30  12.62   65.23
# 2007-05-01  11.52   66.26
# 2007-05-02  11.49   78.09
# 2007-05-03  11.12   79.01
# 2007-05-04  11.29   78.37
# 2007-05-07  11.21   76.40
# 2007-05-08  11.28   77.62
# 2007-05-09  11.22   77.69
# 2007-05-10  10.94   80.55
# 2007-05-11  11.14   81.74
# 2007-05-14  10.96   82.70
# 2007-05-15  10.70   81.10
# 2007-05-16  10.86   82.44
# 2007-05-17  11.23   81.26
# 2007-05-18  11.62   82.00
# 2007-05-21  12.02   81.80
# ...           ...     ...
# 2014-07-21  58.96  589.93
# 2014-07-22  60.26  659.77
# 2014-07-23  60.63  661.27
# 2014-07-24  69.55  660.20
# 2014-07-25  69.11  673.58
# 2014-07-28  69.63  678.01
# 2014-07-29  68.85  674.36
# 2014-07-30  69.22  681.83
# 2014-07-31  66.75  672.50
# 2014-08-01  67.44  675.14
# 2014-08-04  68.28  682.98
# 2014-08-05  68.35  674.71
# 2014-08-06  68.24  673.00
# 2014-08-07  67.74  671.84
# 2014-08-08  68.49  669.70
# 2014-08-11  68.90  680.54
# 2014-08-12  68.36  676.23
# 2014-08-13  69.09  683.68
# 2014-08-14  68.80  679.29
# 2014-08-15  68.84  678.18
# 2014-08-18  70.18  684.83
# 2014-08-19  70.12  681.08
# 2014-08-20  70.56  678.41
# 2014-08-21  69.44  681.07
# 2014-08-22  70.62  676.95
# 2014-08-25  70.55  676.24
# 2014-08-26  70.82  683.89
# 2014-08-27  70.06  677.03
# 2014-08-28  69.68  677.84
# 2014-08-29  68.36  678.65
#
# [1863 rows x 11 columns]

# %% [markdown]
# ### Plot the daily close prices.

# %%
prices[['vti', 'bnd', 'iau']].plot()  # plot a few, or...
#prices.plot()  # plot all
ylabel('Daily Close')

# %% [markdown]
# ### Plot prices normalized from Day 1.

# %%
prices_norm = prices.copy()
for symbol in symbols:
    prices_norm[symbol] = prices[symbol]/prices[symbol][0]
prices_norm[['vti', 'bnd', 'iau']].plot()

# %% [markdown]
# ### Plot the ratio VTI/IAU.

# %% [markdown]
# In 2013-14, stocks are increasing faster than gold.

# %%
(prices_norm.vti/prices_norm.iau).plot(logy=True)
ylim(0.3, 1.5)
# Out:
# (0.3, 1.5)

# %% [markdown]
# ## 2. Data Analysis

# %% [markdown]
# ### Compute the daily percent change.

# %%
prices.pct_change()
# Out:
#                  blv       bnd       bsv       gld       iau       slv  \
# 2007-04-10       NaN       NaN       NaN       NaN       NaN       NaN
# 2007
# 2014-08-27 -0.000578 -0.003871  0.012291 -0.010731 -0.010031
# 2014-08-28 -0.001061 -0.003886  0.001175 -0.005424  0.001196
# 2014-08-29  0.002993  0.006608  0.002445 -0.018944  0.001195
#
# [1863 rows x 11 columns]

# %% [markdown]
# ### Get basic statistics for the daily percent change.

# %%
prices_norm.pct_change().describe()
# Out:
#                blv          bnd          bsv          gld          iau  \
# count  1862.000000  1862.000000  1862.000000  1862.000000  1862.000000
# mean      0.000342     0.000194     0.000136     0.000415     0.000420
# std       0.007119     0.003227     0.002407     0.013164     0.013187
# min      -0.046593    -0.031270    -0.033143    -0.087808    -0.088459
# 25%      -0.003901    -0.001293    -0.000565    -0.005699    -0.005549
# 50%       0.000651     0.000271     0.000126     0.000520     0.000632
# 75%       0.004700     0.001776     0.000838     0.007492     0.007450
# max       0.029781     0.041616     0.026176     0.112905     0.117493
#
#                slv          vti          vbk         aapl           ua  \
# count  1862.000000  1862.000000  1862.000000  1862.000000  1862.000000
# mean      0.000423     0.000378     0.000488     0.001363     0.001422
# std       0.022706     0.014378     0.017048     0.022125     0.032993
# min      -0.179916    -0.093715    -0.107803    -0.179104    -0.244876
# 25%      -0.010297    -0.005255    -0.006900    -0.009156    -0.015223
# 50%       0.001084     0.000945     0.001241     0.001447     0.001477
# 75%       0.012415     0.006596     0.009326     0.012953     0.017088
# max       0.144231     0.128459     0.107268     0.139163     0.262693
#
#                cmg
# count  1862.000000
# mean      0.001633
# std       0.027145
# min      -0.215124
# 25%      -0.011379
# 50%       0.001088
# 75%       0.013418
# max       0.178539

# %% [markdown]
# ### Compute the correlation between each pair of ETFs.

# %%
C = prices_norm.pct_change().corr()
C
# Out:
#            blv       bnd       bsv       gld       iau       slv       vti  \
# blv   1.000000  0.702779  0.410194  0.088813  0.090551 -0.006457 -0.333272
# bnd   0.702779  1.000000  0.377695  0.113126  0.110430  0.075760 -0.157166
# bsv   0.410194  0.377695  1.000000  0.046217  0.054114  0.008785 -0.238130
# gld   0.088813  0.113126  0.046217  1.000000  0.996146  0.806002  0.066420
# iau   0.090551  0.110430  0.054114  0.996146  1.000000  0.807067  0.062328
# slv  -0.006457  0.075760  0.008785  0.806002  0.807067  1.000000  0.244238
# vti  -0.333272 -0.157166 -0.238130  0.066420  0.062328  0.244238  1.000000
# vbk  -0.340893 -0.189291 -0.220619  0.080136  0.075236  0.256232  0.949863
# aapl -0.223472 -0.154763 -0.206884 -0.002146 -0.004353  0.127045  0.601944
# ua   -0.212146 -0.176189 -0.113884  0.008711  0.010168  0.076014  0.559506
# cmg  -0.172751 -0.138986 -0.142591  0.008974  0.006984  0.088322  0.510894
#
#            vbk      aapl        ua       cmg
# blv  -0.340893 -0.223472 -0.212146 -0.172751
# bnd  -0.189291 -0.154763 -0.176189 -0.138986
# bsv  -0.220619 -0.206884 -0.113884 -0.142591
# gld   0.080136 -0.002146  0.008711  0.008974
# iau   0.075236 -0.004353  0.010168  0.006984
# slv   0.256232  0.127045  0.076014  0.088322
# vti   0.949863  0.601944  0.559506  0.510894
# vbk   1.000000  0.594430  0.592606  0.542111
# aapl  0.594430  1.000000  0.352682  0.366849
# ua    0.592606  0.352682  1.000000  0.410490
# cmg   0.542111  0.366849  0.410490  1.000000

# %% [markdown]
# ### Cluster the stocks based upon their pairwise correlations.

# %% [markdown]
# Not surprisingly, the securities cluster by stocks, bonds, and commodities! And that's *without* predefining the number of clusters.

# %%
_, labels = cluster.affinity_propagation(C)
for label in range(max(labels)+1):
    print label, symbols[labels==label]
# Out:
# 0 ['blv' 'bnd' 'bsv']
# 1 ['gld' 'iau' 'slv']
# 2 ['vti' 'vbk' 'aapl' 'ua' 'cmg']

# %% [markdown]
# ### Plot histograms of the daily percent change.

# %% [markdown]
# We find that the daily percent change is roughly Gaussian, which implies that the daily change follows a log-normal distribution.

# %%
prices.pct_change().hist(column=['vti', 'iau', 'bnd', 'cmg'], bins=40, sharex=True, sharey=True)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x10aa02890>,
#         <matplotlib.axes.AxesSubplot object at 0x11033e190>],
#        [<matplotlib.axes.AxesSubplot object at 0x110329b90>,
#         <matplotlib.axes.AxesSubplot object at 0x110580a10>]], dtype=object)

# %% [markdown]
# ### Scatter plot the daily percent change between BND and VTI.

# %% [markdown]
# There is a slight inverse correlation between BND and VTI.

# %% [markdown]
# The plot also suggests that the joint daily change is *jointly Gaussian*. If two jointly Gaussian variables are uncorrelated, then they are *statistically independent*.
#
# That is a good property to have when choosing securities for your portfolio. If two securities are perfectly correlated, well, then you should just own more of one. If two securities are perfectly inversely correlated, then their movements cancel out, so it's as if you're investing less. By choosing statistically independent securities, we have a broader range of risk vs. reward combinations.

# %%
scatter(prices.bnd.pct_change(), prices.vti.pct_change())
xlabel('BND')
ylabel('VTI')

# %% [markdown]
# ## 3. Portfolio Assignment

# %% [markdown]
# As shown earlier, the securities cluster into three categories: stocks, bonds, and commodities. So let's choose one from each.

# %% [markdown]
# ### Get statistics for a portfolio with positions in VTI, BND, and IAU.

# %%
# assuming you use these proportions on day 1
portfolio = 0.5*prices_norm.vti + 0.3*prices_norm.bnd + 0.2*prices_norm.iau
portfolio.pct_change().describe()
# Out:
# count    1862.000000
# mean        0.000287
# std         0.006880
# min        -0.046204
# 25%        -0.002805
# 50%         0.000677
# 75%         0.003701
# max         0.056634
# dtype: float64

# %% [markdown]
# ### Get statistics for a portfolio that is partially allocated in VTI and partially unallocated.

# %% [markdown]
# Compared to the previous portfolio, this portfolio has similar reward but far more risk.

# %%
(0.8*prices_norm.vti + 0.2).pct_change().describe()
# Out:
# count    1862.000000
# mean        0.000289
# std         0.010888
# min        -0.069243
# 25%        -0.004218
# 50%         0.000764
# 75%         0.005253
# max         0.092059
# dtype: float64

# %% [markdown]
# ### Plot the risk and reward of a portfolio with varying positions in VTI and IAU.

# %%
pct_vti = linspace(0, 1, 100, endpoint=False)
vti_iau = pandas.DataFrame({
    'reward': pandas.Series([(r*prices_norm.vti + (1-r)*prices_norm.iau).pct_change().mean() for r in pct_vti], index=pct_vti),
    'risk': pandas.Series([(r*prices_norm.vti + (1-r)*prices_norm.iau).pct_change().std() for r in pct_vti], index=pct_vti)
})
ax = vti_iau.plot(secondary_y='risk')
ax.set_xlabel('Percent of portfolio in VTI')
ax.set_ylabel('Mean of daily percent change')
ax.right_ax.set_ylabel('Standard deviation of daily percent change')
title('VTI vs. IAU: Reward and Risk')

# %% [markdown]
# ### Plot risk vs. reward.

# %%
reward_over_risk = vti_iau.reward/vti_iau.risk
reward_over_risk.plot()
xlabel('Percent of portfolio in VTI')
ylabel('Reward/Risk')

# %% [markdown]
# ### Compute optimal allocation between VTI and IAU.

# %% [markdown]
# Reward/risk is maximized when the portfolio is approximately 53% VTI and 47% IAU.

# %%
reward_over_risk.argmax()
# Out:
# 0.53000000000000003

# %% [markdown]
# ### Repeat for VTI and BND.

# %%
vti_bnd = pandas.DataFrame({
    'reward': pandas.Series([(r*prices_norm.vti + (1-r)*prices_norm.bnd).pct_change().mean() for r in pct_vti], index=pct_vti),
    'risk': pandas.Series([(r*prices_norm.vti + (1-r)*prices_norm.bnd).pct_change().std() for r in pct_vti], index=pct_vti)
})
ax = vti_bnd.plot(secondary_y='risk')
ax.set_xlabel('Percent of portfolio in VTI')
ax.set_ylabel('Mean of daily percent change')
ax.right_ax.set_ylabel('Standard deviation of daily percent change')
title('VTI vs. BND: Reward and Risk')

# %%
reward_over_risk = vti_bnd.reward/vti_bnd.risk
reward_over_risk.plot()
xlabel('Percent of portfolio in VTI')
ylabel('Reward/Risk')

# %% [markdown]
# Reward/risk is mazimized at 14% VTI and 86% BND.

# %%
reward_over_risk.argmax()
# Out:
# 0.14000000000000001

# %% [markdown]
# ### Find the maximum reward given a risk constraint.

# %% [markdown]
# Suppose that we require the standard deviation of the daily percent change to be less than 0.01.

# %% [markdown]
# Given this risk constraint, reward is maximized at 77% VTI and 23% BND.

# %%
vti_bnd[vti_bnd.risk < 0.01].iloc[-1]
# Out:
# reward    0.000305
# risk      0.009914
# Name: 0.77, dtype: float64

# %% [markdown]
# ### Plot the trajectory of three hypothetical portfolios.

# %%
portfolios = pandas.DataFrame({
    'bnd heavy': 0.15*prices_norm.vti + 0.15*prices_norm.iau + 0.70*prices_norm.bnd,
    'iau heavy': 0.15*prices_norm.vti + 0.70*prices_norm.iau + 0.15*prices_norm.bnd,
    'vti heavy': 0.70*prices_norm.vti + 0.15*prices_norm.iau + 0.15*prices_norm.bnd,
    'mixed':     0.45*prices_norm.vti + 0.43*prices_norm.iau + 0.12*prices_norm.bnd,
})
portfolios.plot()

# %% [markdown]
# ### Get the statistics of these portfolios.

# %%
portfolios.pct_change().describe()
# Out:
#          bnd heavy    iau heavy        mixed    vti heavy
# count  1862.000000  1862.000000  1862.000000  1862.000000
# mean      0.000234     0.000359     0.000331     0.000313
# std       0.003890     0.010463     0.008880     0.009056
# min      -0.041132    -0.073167    -0.061664    -0.062108
# 25%      -0.001551    -0.004388    -0.003737    -0.003566
# 50%       0.000360     0.000688     0.000750     0.000846
# 75%       0.002189     0.006091     0.004882     0.004877
# max       0.038908     0.080825     0.055899     0.077049

# %% [markdown]
# So what does this all mean? I have no idea.
