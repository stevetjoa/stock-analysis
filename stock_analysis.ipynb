# %% [markdown]
# # Stock Analysis

# %% [markdown]
# This notebook analyzes some securities -- stocks, bonds, commodities -- computes their correlations, and optimizes risk vs. reward for a set of portfolio scenarios.

# %% [markdown]
# Select "Run All" to update this notebook with the latest stock quotes.

# %% [markdown]
# Caveat: This analysis covers a date range starting around 2007 (if run without modification). Obviously, the analysis can vary dramatically if you choose another date range.

# %% [markdown]
# ### Initialization

# %%
from sklearn import cluster  # machine learning
import pandas             # data manipulation and computation
import ystockquote as ys  # stock prices

# %%
rcParams['figure.figsize'] = (13, 6)  # default figure size

# %% [markdown]
# ## 1. Data Collection

# %% [markdown]
# ### Choose a few securities.

# %%
symbols = array([
           'blv',  # bond: long-term bond
           'bnd',  # bond: total bond market
           'bsv',  # bond: short-term bond
           'tip',  # bond: treasury inflation protected
           'gld',  # commodity: gold (SPDR)
           'iau',  # commodity: gold (iShares)
           'slv',  # commodity: silver
           'vti',  # stock: US total stock market
           'vbk',  # stock: US small-cap stock
           'aapl', # stock: Apple
           'ua',   # stock: Under Armour
           'cmg',  # stock: Chipotle
          ])

# %% [markdown]
# ### Get daily close prices.

# %%
prices = pandas.DataFrame({
             symbol: {
                 date: quote['Adj Close'] 
                 for date, quote in ys.get_historical_prices(symbol, '2000-01-01', '2015-01-01').iteritems()
             }
             for symbol in symbols
         }, columns=symbols, dtype=float)
prices.head()
# Out:
#             blv  bnd  bsv  tip  gld  iau  slv  vti  vbk  aapl  ua  cmg
# 2000-01-03  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  3.80 NaN  NaN
# 2000-01-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  3.48 NaN  NaN
# 2000-01-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  3.53 NaN  NaN
# 2000-01-06  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  3.23 NaN  NaN
# 2000-01-07  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  3.38 NaN  NaN

# %%
prices.tail()
# Out:
#               blv    bnd    bsv     tip     gld    iau    slv     vti     vbk  \
# 2014-10-20  93.00  82.98  80.60  114.04  119.80  12.07  16.73   98.09  117.53
# 2014-10-21  92.66  82.86  80.57  113.81  120.02  12.08  16.81  100.03  119.87
# 2014-10-22  92.51  82.84  80.57  113.76  119.34  12.03  16.46   99.25  118.29
# 2014-10-23  92.03  82.59  80.48  113.35  118.52  11.94  16.50  100.45  120.09
# 2014-10-24  92.02  82.66  80.43  113.29  118.35  11.92  16.50  101.15  120.32
#
#               aapl     ua     cmg
# 2014-10-20   99.76  65.11  653.03
# 2014-10-21  102.47  67.45  607.55
# 2014-10-22  102.99  66.05  608.99
# 2014-10-23  104.83  64.34  610.00
# 2014-10-24  105.22  64.25  615.78

# %% [markdown]
# ### Only preserve dates for which all stocks exist.

# %%
prices.dropna(inplace=True)
prices.head()
# Out:
#               blv    bnd    bsv    tip    gld   iau    slv    vti    vbk  \
# 2007-04-10  51.14  57.86  62.48  78.08  67.16  6.71  13.85  62.02  66.83
# 2007-04-11  51.07  57.70  62.45  77.96  67.08  6.71  13.77  61.62  66.59
# 2007-04-12  51.13  57.69  62.59  77.96  66.99  6.71  13.81  62.03  67.16
# 2007-04-13  51.03  57.60  62.42  77.77  67.84  6.79  13.99  62.24  67.51
# 2007-04-16  51.20  57.66  62.49  78.01  68.40  6.84  13.98  62.86  68.31
#
#              aapl     ua    cmg
# 2007-04-10  12.81  13.26  64.67
# 2007-04-11  12.58  13.17  63.78
# 2007-04-12  12.53  13.16  64.16
# 2007-04-13  12.26  12.97  64.07
# 2007-04-16  12.42  13.13  65.20

# %% [markdown]
# ### Plot the daily close prices.

# %%
prices[['vti', 'bnd', 'iau']].plot()  # plot a few, or...
#prices.plot()  # plot all
ylabel('Daily Close')

# %% [markdown]
# ### Plot prices normalized from Day 1.

# %%
prices_norm = prices.copy()
for symbol in symbols:
    prices_norm[symbol] = prices[symbol]/prices[symbol][0]
prices_norm[['vti', 'bnd', 'iau']].plot()

# %% [markdown]
# ### Plot the ratio VTI/IAU.

# %% [markdown]
# In 2013-14, stocks are increasing faster than gold.

# %%
(prices_norm.vti/prices_norm.iau).plot(logy=True)
ylim(0.3, 1.5)
# Out:
# (0.3, 1.5)

# %% [markdown]
# ## 2. Data Analysis

# %% [markdown]
# ### Compute the daily percent change.

# %%
prices.pct_change().tail()
# Out:
#                  blv       bnd       bsv       tip       gld       iau  \
# 2014-10-20 -0.000752  0.000844  0.000248  0.000351  0.006807  0.006672
# 2014-10-21 -0.003656 -0.001446 -0.000372 -0.002017  0.001836  0.000829
# 2014-10-22 -0.001619 -0.000241  0.000000 -0.000439 -0.005666 -0.004139
# 2014-10-23 -0.005189 -0.003018 -0.001117 -0.003604 -0.006871 -0.007481
# 2014-10-24 -0.000109  0.000848 -0.000621 -0.000529 -0.001434 -0.001675
#
#                  slv       vti       vbk      aapl        ua       cmg
# 2014-10-20  0.009047  0.009988  0.013277  0.021399 -0.000307  0.017625
# 2014-10-21  0.004782  0.019778  0.019910  0.027165  0.035939 -0.069645
# 2014-10-22 -0.020821 -0.007798 -0.013181  0.005075 -0.020756  0.002370
# 2014-10-23  0.002430  0.012091  0.015217  0.017866 -0.025889  0.001658
# 2014-10-24  0.000000  0.006969  0.001915  0.003720 -0.001399  0.009475

# %% [markdown]
# ### Get basic statistics for the daily percent change.

# %%
prices.pct_change().describe()
# Out:
#                blv          bnd          bsv          tip          gld  \
# count  1901.000000  1901.000000  1901.000000  1901.000000  1901.000000
# mean      0.000334     0.000193     0.000136     0.000206     0.000383
# std       0.007086     0.003205     0.002384     0.004517     0.013065
# min      -0.046689    -0.031076    -0.033208    -0.029606    -0.087808
# 25%      -0.003846    -0.001294    -0.000590    -0.002133    -0.005690
# 50%       0.000645     0.000257     0.000126     0.000256     0.000515
# 75%       0.004692     0.001753     0.000801     0.002708     0.007338
# max       0.029747     0.041616     0.026073     0.036962     0.112905
#
#                iau          slv          vti          vbk         aapl  \
# count  1901.000000  1901.000000  1901.000000  1901.000000  1901.000000
# mean      0.000388     0.000349     0.000359     0.000453     0.001351
# std       0.013088     0.022530     0.014292     0.016950     0.022005
# min      -0.088459    -0.179916    -0.093686    -0.107803    -0.179104
# 25%      -0.005542    -0.010146    -0.005215    -0.007215    -0.009133
# 50%       0.000632     0.001050     0.000945     0.001270     0.001444
# 75%       0.007364     0.012160     0.006617     0.009215     0.012876
# max       0.117493     0.144231     0.128539     0.107268     0.139163
#
#                 ua          cmg
# count  1901.000000  1901.000000
# mean      0.001365     0.001551
# std       0.032793     0.026957
# min      -0.244876    -0.215124
# 25%      -0.015270    -0.011372
# 50%       0.001422     0.000957
# 75%       0.017065     0.013281
# max       0.262693     0.178539

# %% [markdown]
# ### Compute the correlation between each pair of ETFs.

# %%
C = prices.pct_change().corr()
C
# Out:
#            blv       bnd       bsv       tip       gld       iau       slv  \
# blv   1.000000  0.704557  0.410234  0.688522  0.091922  0.093646 -0.005384
# bnd   0.704557  1.000000  0.380864  0.652839  0.115897  0.113298  0.076869
# bsv   0.410234  0.380864  1.000000  0.449455  0.049351  0.057301  0.010269
# tip   0.688522  0.652839  0.449455  1.000000  0.199849  0.203175  0.130774
# gld   0.091922  0.115897  0.049351  0.199849  1.000000  0.996121  0.805610
# iau   0.093646  0.113298  0.057301  0.203175  0.996121  1.000000  0.806627
# slv  -0.005384  0.076869  0.010269  0.130774  0.805610  0.806627  1.000000
# vti  -0.332156 -0.158850 -0.239067 -0.234577  0.065109  0.060981  0.243642
# vbk  -0.339958 -0.190846 -0.221153 -0.223332  0.079031  0.074054  0.255766
# aapl -0.224958 -0.156991 -0.208019 -0.202059 -0.002892 -0.005129  0.127048
# ua   -0.213502 -0.177627 -0.114968 -0.160950  0.007170  0.008624  0.075585
# cmg  -0.170502 -0.138700 -0.142605 -0.153652  0.007864  0.006067  0.087410
#
#            vti       vbk      aapl        ua       cmg
# blv  -0.332156 -0.339958 -0.224958 -0.213502 -0.170502
# bnd  -0.158850 -0.190846 -0.156991 -0.177627 -0.138700
# bsv  -0.239067 -0.221153 -0.208019 -0.114968 -0.142605
# tip  -0.234577 -0.223332 -0.202059 -0.160950 -0.153652
# gld   0.065109  0.079031 -0.002892  0.007170  0.007864
# iau   0.060981  0.074054 -0.005129  0.008624  0.006067
# slv   0.243642  0.255766  0.127048  0.075585  0.087410
# vti   1.000000  0.949285  0.601165  0.560273  0.508812
# vbk   0.949285  1.000000  0.592603  0.593807  0.539952
# aapl  0.601165  0.592603  1.000000  0.352062  0.364091
# ua    0.560273  0.593807  0.352062  1.000000  0.408907
# cmg   0.508812  0.539952  0.364091  0.408907  1.000000

# %% [markdown]
# ### Cluster the stocks based upon their pairwise correlations.

# %% [markdown]
# Not surprisingly, the securities cluster by stocks, bonds, and commodities! And that's *without* predefining the number of clusters.

# %%
_, labels = cluster.affinity_propagation(C)
for label in range(max(labels)+1):
    print label, symbols[labels==label]
# Out:
# 0 ['blv' 'bnd' 'bsv' 'tip']
# 1 ['gld' 'iau' 'slv']
# 2 ['vti' 'vbk' 'aapl' 'ua' 'cmg']

# %% [markdown]
# ### Plot histograms of the daily percent change.

# %% [markdown]
# We find that the daily percent change is roughly Gaussian, which implies that the daily change follows a log-normal distribution.

# %%
prices.pct_change().hist(column=['vti', 'iau', 'bnd', 'cmg'], bins=40, sharex=True, sharey=True)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x10866f390>,
#         <matplotlib.axes.AxesSubplot object at 0x108702c50>],
#        [<matplotlib.axes.AxesSubplot object at 0x1087213d0>,
#         <matplotlib.axes.AxesSubplot object at 0x1084ee290>]], dtype=object)

# %% [markdown]
# ### Scatter plot the daily percent change between BND and VTI.

# %% [markdown]
# There is a slight inverse correlation between BND and VTI.

# %% [markdown]
# The plot also suggests that the joint daily change is *jointly Gaussian*. If two jointly Gaussian variables are uncorrelated, then they are *statistically independent*.
#
# That is a good property to have when choosing securities for your portfolio. If two securities are perfectly correlated, well, then you should just own more of one. If two securities are perfectly inversely correlated, then their movements cancel out, so it's as if you're investing less. By choosing statistically independent securities, we have a broader range of risk vs. reward combinations.

# %%
scatter(prices.bnd.pct_change(), prices.vti.pct_change())
xlabel('BND')
ylabel('VTI')

# %% [markdown]
# ## 3. Portfolio Assignment

# %% [markdown]
# As shown earlier, the securities cluster into three categories: stocks, bonds, and commodities. So let's choose one from each.

# %% [markdown]
# ### Get statistics for a portfolio with positions in VTI, BND, and IAU.

# %%
# assuming you use these proportions on day 1
portfolio = 0.5*prices_norm.vti + 0.3*prices_norm.bnd + 0.2*prices_norm.iau
portfolio.pct_change().describe()
# Out:
# count    1901.000000
# mean        0.000270
# std         0.006842
# min        -0.046207
# 25%        -0.002840
# 50%         0.000643
# 75%         0.003653
# max         0.056661
# dtype: float64

# %% [markdown]
# ### Get statistics for a portfolio that is partially allocated in VTI and partially unallocated.

# %% [markdown]
# Compared to the previous portfolio, this portfolio has similar reward but far more risk.

# %%
(0.8*prices_norm.vti + 0.2).pct_change().describe()
# Out:
# count    1901.000000
# mean        0.000274
# std         0.010837
# min        -0.069221
# 25%        -0.004158
# 50%         0.000771
# 75%         0.005270
# max         0.092114
# dtype: float64

# %% [markdown]
# ### Plot the risk and reward of a portfolio with varying positions in VTI and IAU.

# %%
pct_vti = linspace(0, 1, 100, endpoint=False)
vti_iau = pandas.DataFrame({
    'reward': pandas.Series([(r*prices_norm.vti + (1-r)*prices_norm.iau).pct_change().mean() for r in pct_vti], index=pct_vti),
    'risk': pandas.Series([(r*prices_norm.vti + (1-r)*prices_norm.iau).pct_change().std() for r in pct_vti], index=pct_vti)
})
ax = vti_iau.plot(secondary_y='risk')
ax.set_xlabel('Percent of portfolio in VTI')
ax.set_ylabel('Mean of daily percent change')
ax.right_ax.set_ylabel('Standard deviation of daily percent change')
title('VTI vs. IAU: Reward and Risk')

# %% [markdown]
# ### Plot risk vs. reward.

# %%
reward_over_risk = vti_iau.reward/vti_iau.risk
reward_over_risk.plot()
xlabel('Percent of portfolio in VTI')
ylabel('Reward/Risk')

# %% [markdown]
# ### Compute optimal allocation between VTI and IAU.

# %% [markdown]
# Reward/risk is maximized when the portfolio is approximately 53% VTI and 47% IAU.

# %%
reward_over_risk.argmax()
# Out:
# 0.54000000000000004

# %% [markdown]
# ### Repeat for VTI and BND.

# %%
vti_bnd = pandas.DataFrame({
    'reward': pandas.Series([(r*prices_norm.vti + (1-r)*prices_norm.bnd).pct_change().mean() for r in pct_vti], index=pct_vti),
    'risk': pandas.Series([(r*prices_norm.vti + (1-r)*prices_norm.bnd).pct_change().std() for r in pct_vti], index=pct_vti)
})
ax = vti_bnd.plot(secondary_y='risk')
ax.set_xlabel('Percent of portfolio in VTI')
ax.set_ylabel('Mean of daily percent change')
ax.right_ax.set_ylabel('Standard deviation of daily percent change')
title('VTI vs. BND: Reward and Risk')

# %%
reward_over_risk = vti_bnd.reward/vti_bnd.risk
reward_over_risk.plot()
xlabel('Percent of portfolio in VTI')
ylabel('Reward/Risk')

# %% [markdown]
# Reward/risk is mazimized at 14% VTI and 86% BND.

# %%
reward_over_risk.argmax()
# Out:
# 0.13

# %% [markdown]
# ### Find the maximum reward given a risk constraint.

# %% [markdown]
# Suppose that we require the standard deviation of the daily percent change to be less than 0.01.

# %% [markdown]
# Given this risk constraint, reward is maximized at 77% VTI and 23% BND.

# %%
vti_bnd[vti_bnd.risk < 0.01].iloc[-1]
# Out:
# reward    0.000291
# risk      0.009866
# Name: 0.77, dtype: float64

# %% [markdown]
# ### Plot the trajectory of three hypothetical portfolios.

# %%
portfolios = pandas.DataFrame({
    'bnd heavy': 0.15*prices_norm.vti + 0.15*prices_norm.iau + 0.70*prices_norm.bnd,
    'iau heavy': 0.15*prices_norm.vti + 0.70*prices_norm.iau + 0.15*prices_norm.bnd,
    'vti heavy': 0.70*prices_norm.vti + 0.15*prices_norm.iau + 0.15*prices_norm.bnd,
    'mixed':     0.45*prices_norm.vti + 0.43*prices_norm.iau + 0.12*prices_norm.bnd,
})
portfolios.plot()

# %% [markdown]
# ### Get the statistics of these portfolios.

# %%
portfolios.pct_change().describe()
# Out:
#          bnd heavy    iau heavy        mixed    vti heavy
# count  1901.000000  1901.000000  1901.000000  1901.000000
# mean      0.000225     0.000334     0.000309     0.000295
# std       0.003864     0.010381     0.008816     0.009009
# min      -0.041208    -0.073174    -0.061649    -0.062046
# 25%      -0.001556    -0.004321    -0.003762    -0.003584
# 50%       0.000357     0.000675     0.000707     0.000808
# 75%       0.002173     0.006011     0.004799     0.004835
# max       0.038915     0.080823     0.055858     0.077093

# %% [markdown]
# So what does this all mean? I have no idea.
